# %%
df = spark.read \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .csv("data/source.csv")

# %%
from pyspark.sql.functions import col

result = df.select("product_id", "price").filter(col("category") == "Electronics")

# %%
from pyspark.sql.functions import col
from pyspark.sql.types import DoubleType

df_revised = df.withColumnRenamed("old_name", "new_name") \
    .withColumn("price", col("price").cast(DoubleType()))

# %%
from pyspark.sql.functions import col

filtered_df = df_orders.filter((col("status") == "Completed") & (col("amount") > 1000))

# %%
from pyspark.sql.functions import col

df_final = df.withColumn("final_price", col("base_price") * 1.18)

# %%
from pyspark.sql.functions import col

df_in = spark.read.parquet("path/to/input")
df_filtered = df_in.filter(col("user_id").isNotNull())

df_filtered.write \
    .option("header", "true") \
    .mode("overwrite") \
    .csv("path/to/output")

# %%
from pyspark.sql.functions import col

df_filtered = df.filter((col("region") == "North") | (col("priority") == "High"))
